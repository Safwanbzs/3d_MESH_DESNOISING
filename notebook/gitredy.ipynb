# %%
from open3d.examples.reconstruction_system.sensors.azure_kinect_mkv_reader import pwd
# !git --version
# Out:
# git version 2.49.0.windows.1

# %%
# !git init
# Out:
# Reinitialized existing Git repository in S:/3d_mesh_denoising/module_3/mesh-denoising/.git/

# %%
# %%writefile .gitignore
# .venv/
# __pycache__/
# *.pyc
# .ipynb_checkpoints/
# .idea/
# Out:
# Writing .gitignore
